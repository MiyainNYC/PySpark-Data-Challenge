#   2013-08-31 23:48:10          2           NaN           NaN         NaN
#   2013-08-31 23:48:29          2           NaN           NaN         NaN
#   2013-08-31 23:50:37          1           NaN           NaN         NaN
#   2013-08-31 23:51:16          2           NaN           NaN         NaN
#   2013-08-31 23:52:57          2           NaN           NaN         NaN
#   2013-08-31 23:54:00          2           NaN           NaN         NaN
#   2013-08-31 23:54:50          2           NaN           NaN         NaN
#   2013-08-31 23:57:33          1           NaN           NaN         NaN
#   2013-08-31 23:58:18          2           NaN           NaN         NaN
#   2013-08-31 23:58:58          2           NaN           NaN         NaN
# 1 2013-08-31 23:59:14          1           NaN           NaN         NaN
#
# [7623 rows x 20 columns]

# %%
len(c.columns)==len(['VendorID','lpep_pickup_datetime','Lpep_dropoff_datetime'
             ,'Store_and_fwd_flag','RateCodeID','Pickup_longitude','Pickup_latitude'
             ,'Dropoff_longitude','Dropoff_latitude'
             ,'Passenger_count','Trip_distance','Fare_amount'
             ,'Extra','MTA_tax'
             ,'Tip_amount','Tolls_amount','Ehail_fee','improvement_surcharge'
             ,'Total_amount','Payment_type','Trip_type '])
# Out:
# False

# %%
c = c[c['VendorID'].isin(list(range(1,3)))!=0]
c = c[c['improvement_surcharge']>0]
c = c[c['Store_and_fwd_flag'].isin(list(['Y','N']))!=0]
c = c[c['RateCodeID'].isin(list(range(1,7)))!=0]
c = c[c['Passenger_count']<=5]
c = c[c['Trip_distance']>0]
c = c[c['Fare_amount']>0]
c = c[c['MTA_tax']>0]
c = c[c['Extra']>0]
c = c[c['Tip_amount']>0]
c = c[c['Tolls_amount']>0]
c = c[c['Total_amount']>0]
c = c[c['Payment_type'].isin(list(range(1,7)))!=0]
c = c[c['Trip_type '].isin(list(range(1,3)))!=0]
# Out:
#                                   VendorID lpep_pickup_datetime  \
# 2 2013-08-01 08:14:37  2013-08-01 09:09:06                    N
#   2013-08-01 09:13:00  2013-08-01 11:38:00                    N
#   2013-08-01 09:48:00  2013-08-01 09:49:00                    N
#   2013-08-01 10:38:35  2013-08-01 10:38:51                    N
#   2013-08-01 11:51:45  2013-08-01 12:03:52                    N
#   2013-08-01 14:33:39  2013-08-01 15:49:00                    N
#   2013-08-01 17:19:00  2013-08-01 17:19:00                    N
#   2013-08-01 17:22:00  2013-08-01 17:22:00                    N
#   2013-08-01 17:24:00  2013-08-01 17:25:00                    N
#   2013-08-01 19:21:09  2013-08-01 19:22:30                    N
#   2013-08-01 19:29:27  2013-08-01 19:32:38                    N
#   2013-08-01 19:33:28  2013-08-01 19:35:21                    N
#   2013-08-02 09:37:44  2013-08-02 09:38:08                    N
#   2013-08-02 09:43:58  2013-08-02 09:44:13                    N
#   2013-08-02 09:44:43  2013-08-02 09:45:15                    N
#   2013-08-02 11:26:32  2013-08-02 11:26:54                    N
#   2013-08-02 11:32:36  2013-08-02 11:45:45                    N
#   2013-08-02 11:46:27  2013-08-02 11:47:32                    N
#   2013-08-02 12:10:46  2013-08-02 12:11:45                    N
#   2013-08-02 12:19:55  2013-08-02 12:20:11                    N
#   2013-08-02 12:30:00  2013-08-02 18:08:00                    N
#   2013-08-05 09:01:22          2           NaN           NaN         NaN
#   2013-08-05 10:16:04          2           NaN           NaN         NaN
#   2013-08-05 11:05:58          2           NaN           NaN         NaN
#   2013-08-05 11:14:37          2           NaN           NaN         NaN
# ...                          ...           ...           ...         ...
# 1 2013-08-31 23:23:38          2           NaN           NaN         NaN
# 2 2013-08-31 23:23:45          1           NaN           NaN         NaN
#   2013-08-31 23:23:49          2           NaN           NaN         NaN
#   2013-08-31 23:24:42          2           NaN           NaN         NaN
#   2013-08-31 23:25:05          2           NaN           NaN         NaN
#   2013-08-31 23:27:26          1           NaN           NaN         NaN
#   2013-08-31 23:27:46          1           NaN           NaN         NaN
#   2013-08-31 23:28:21          2           NaN           NaN         NaN
#   2013-08-31 23:30:53          1           NaN           NaN         NaN
#   2013-08-31 23:33:19          2           NaN           NaN         NaN
#   2013-08-31 23:34:00          2           NaN           NaN         NaN
#   2013-08-31 23:34:55          2           NaN           NaN         NaN
#   2013-08-31 23:34:58          1           NaN           NaN         NaN
#   2013-08-31 23:35:21          2           NaN           NaN         NaN
#   2013-08-31 23:40:04          2           NaN           NaN         NaN
#   2013-08-31 23:41:33          2           NaN           NaN         NaN
#   2013-08-31 23:44:17          1           NaN           NaN         NaN
# 1 2013-08-31 23:45:43          2           NaN           NaN         NaN
# 2 2013-08-31 23:46:58          2           NaN           NaN         NaN
#   2013-08-31 23:48:10          2           NaN           NaN         NaN
#   2013-08-31 23:48:29          2           NaN           NaN         NaN
#   2013-08-31 23:50:37          1           NaN           NaN         NaN
#   2013-08-31 23:51:16          2           NaN           NaN         NaN
#   2013-08-31 23:52:57          2           NaN           NaN         NaN
#   2013-08-31 23:54:00          2           NaN           NaN         NaN
#   2013-08-31 23:54:50          2           NaN           NaN         NaN
#   2013-08-31 23:57:33          1           NaN           NaN         NaN
#   2013-08-31 23:58:18          2           NaN           NaN         NaN
#   2013-08-31 23:58:58          2           NaN           NaN         NaN
# 1 2013-08-31 23:59:14          1           NaN           NaN         NaN
#
# [7623 rows x 20 columns]

# %%
import pandas as pd
import io
import requests
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
from geopy.geocoders import Nominatim
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline


years = ['2013']#, '2014', '2015', '2016']
months = ['01','02','03','04','05','06','07','08','09','10','11','12']

for year in years:
    for month in months:
        url = 'https://s3.amazonaws.com/nyc-tlc/trip+data/green_tripdata_'+year+'-'+month+'.csv'
        try:
            s=requests.get(url).content
            c=pd.read_csv(io.StringIO(s.decode('utf-8')))
            shape_origin = c.shape
            print('%s :%s'%(year,month))
            
            c = c[c['VendorID'].isin(list(range(1,3)))!=0]
            c = c[c['Store_and_fwd_flag'].isin(list(['Y','N']))!=0]
            c = c[c['RateCodeID'].isin(list(range(1,7)))!=0]
            c = c[c['Passenger_count']<=5]
            c = c[c['Trip_distance']>0]
            c = c[c['Fare_amount']>0]
            c = c[c['MTA_tax']>0]
            c = c[c['Extra']>0]
            c = c[c['Tip_amount']>0]
            c = c[c['Tolls_amount']>0]
            c = c[c['improvement_surcharge']>0]
            c = c[c['Total_amount']>0]
            c = c[c['Payment_type'].isin(list(range(1,7)))!=0]
            c = c[c['Trip_type '].isin(list(range(1,3)))!=0]

            
            c['lpep_pickup_datetime'] = pd.to_datetime(c['lpep_pickup_datetime'],format = '%Y-%m-%d %H:%M:%S')
            c['Lpep_dropoff_datetime'] = pd.to_datetime(c['Lpep_dropoff_datetime'],format = '%Y-%m-%d %H:%M:%S')
            c['interval_min'] = list(map(lambda x:x/60,list(map(lambda x: x.total_seconds(), list(c['Lpep_dropoff_datetime'] - c['lpep_pickup_datetime'])))))
            c = c[c['interval_min']>0]
            c = c[c['Trip_distance']/c['interval_min']<0.417]
            
            print('%s rows deleted, %s rows remained'%((shape_origin[0]- len(c)),len(c)))       
            
            c['weekofday'] = list(map(lambda x: x.weekday(), c['lpep_pickup_datetime']))
            c['hour'] = list(map(lambda x: x.hour, c['lpep_pickup_datetime']))
            c['day'] = list(map(lambda x: x.day, c['lpep_pickup_datetime']))
            c['month'] = list(map(lambda x: x.month, c['lpep_pickup_datetime']))
            c['year'] = list(map(lambda x: x.year, c['lpep_pickup_datetime']))
            c['date'] = list(map(lambda x: x.date(), c['lpep_pickup_datetime']))
            #c['date'] =  pd.to_datetime(c['date'], format='%d%b%Y:%H:%M:%S.%f')
            
            
            year = c['year'].values[0]
            start = str(year)+'-01-01'
            end = str(year)+'-12-31'
            
            dr = pd.date_range(start=start, end=end)
            cal = calendar()
            holidays = cal.holidays(start=dr.min(), end=dr.max())
            
            c['Holiday'] = c['date'].isin(holidays)
            
            print('%d columns added'%(c.shape[1]-shape_origin[1]))
            
            
            col_del = ['VendorID','lpep_pickup_datetime','Lpep_dropoff_datetime','Pickup_longitude',
                       'Pickup_latitude','Dropoff_longitude','Dropoff_latitude','Ehail_fee']
            for col in col_del:
                c = c.drop(col, 1)
            
            print('final shape:%s rows %s columns'%(c.shape[0],c.shape[1]))
            
            print(c.head())
        
        except KeyError:
                  pass
# Out:
# 2013 :01
# 2013 :02
# 2013 :03
# 2013 :04
# 2013 :05
# 2013 :06
# 2013 :07
# 2013 :08
# 2013 :09
# 2013 :10
# 2013 :11
# 2013 :12

# %%
shape_origin = c.shape
print(c.shape)
# Out:
# (3705, 29)

# %%
c['lpep_pickup_datetime'] = pd.to_datetime(c['lpep_pickup_datetime'],format = '%Y-%m-%d %H:%M:%S')
c['Lpep_dropoff_datetime'] = pd.to_datetime(c['Lpep_dropoff_datetime'],format = '%Y-%m-%d %H:%M:%S')
c['interval_min'] = list(map(lambda x:x/60,list(map(lambda x: x.total_seconds(), list(c['Lpep_dropoff_datetime'] - c['lpep_pickup_datetime'])))))

# %%
c = c[c['VendorID'].isin(list(range(1,3)))!=0]
c = c[c['Store_and_fwd_flag'].isin(list(['Y','N']))!=0]
c = c[c['RateCodeID'].isin(list(range(1,7)))!=0]
c = c[c['Passenger_count']<=5]
c = c[c['Trip_distance']>0]
c = c[c['Fare_amount']>0]
c = c[c['MTA_tax']>0]
c = c[c['Extra']>0]
c = c[c['Tip_amount']>0]
c = c[c['Tolls_amount']>0]
c = c[c['improvement_surcharge']>0]
c = c[c['Total_amount']>0]
c = c[c['Payment_type'].isin(list(range(1,7)))!=0]
c = c[c['Trip_type '].isin(list(range(1,3)))!=0]
c = c[c['Trip_distance']/c['interval_min']<0.417]

print('%s rows deleted, %s rows remained'%((shape_origin[0]- len(c)),len(c)))
# Out:
# 1507017 rows deleted, 3705 rows remained

# %% [markdown]
# http://nymag.com/daily/intelligencer/2014/11/things-to-know-about-nycs-new-speed-limit.html

# %%
c['weekofday'] = list(map(lambda x: x.weekday(), c['lpep_pickup_datetime']))
c['hour'] = list(map(lambda x: x.hour, c['lpep_pickup_datetime']))
c['day'] = list(map(lambda x: x.day, c['lpep_pickup_datetime']))
c['month'] = list(map(lambda x: x.month, c['lpep_pickup_datetime']))
c['year'] = list(map(lambda x: x.year, c['lpep_pickup_datetime']))
c['date'] = list(map(lambda x: x.date(), c['lpep_pickup_datetime']))
#c['date'] =  pd.to_datetime(c['date'], format='%d%b%Y:%H:%M:%S.%f')

year = c['year'].values[0]


from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
start = str(year)+'-01-01'
end = str(year)+'-12-31'
dr = pd.date_range(start=start, end=end)

cal = calendar()
holidays = cal.holidays(start=dr.min(), end=dr.max())
c['Holiday'] = c['date'].isin(holidays)
print('%d columns added'%(c.shape[1]-shape_origin[1]))
# Out:
# 8 columns added

# %%
col_del = ['VendorID','lpep_pickup_datetime','Lpep_dropoff_datetime','Pickup_longitude',
          'Pickup_latitude','Dropoff_longitude','Dropoff_latitude','Ehail_fee']
for col in col_del:
    c = c.drop(col, 1)
print('final shape:%s rows %s columns'%(c.shape[0],c.shape[1]))
# Out:
# final shape:3705 rows 21 columns

# %%
c.isnull().any().count()
# Out:
# 21

# %%
c['date'].values[6]
# Out:
# datetime.date(2016, 2, 1)

# %%
col_geo = ['Pickup_longitude','Pickup_latitude','Dropoff_longitude','Dropoff_latitude']
for col in col_geo:
    c[col] = c[col].astype('str')
    
geolocator = Nominatim()
pickup_lat_long = zip(c['Pickup_latitude'],c['Pickup_longitude'])
dropoff_lat_long = zip(c['Dropoff_latitude'],c['Dropoff_longitude'])
pickup_zipcode = []
dropoff_zipcode = []

for i,j in pickup_lat_long:
    try:
        zipcode = geolocator.reverse(','.join([i,j]),timeout=10).address.split(',')[-2].strip()
        pickup_zipcode.append(zipcode)
    except AttributeError:
        pickup_zipcode.append(' ')
        
for i,j in dropoff_lat_long:
    try:
        zipcode = geolocator.reverse(','.join([i,j]),timeout=10).address.split(',')[-2].strip()
        dropoff_zipcode.append(zipcode)
    except AttributeError:
        dropoff_zipcode.append(' ')
    
c['pickup_zipcode'] = pickup_zipcode
c['dropoff_zipcode'] = dropoff_zipcode

# %%
12/60
# Out:
# 0.2

# %%
25/60
# Out:
# 0.4166666666666667

# %% [markdown]
# The maximum amount of passengers allowed in a yellow taxicab by law is four (4) in a four (4) passenger taxicab or five (5) passengers in a five (5) passenger taxicab, except that an additional passenger must be accepted if such passenger is under the age of seven (7) and is held on the lap of an adult passenger seated in the rear.

# %%
start
# Out:
# '2016-2-01'

# %%
start = datetime.datetime.strptime('2016-02-01', '%Y-%m-%d')
end = datetime.datetime.strptime('2016-02-15', '%Y-%m-%d')

# %%
df = c[(c['lpep_pickup_datetime'] >= start) & (c['lpep_pickup_datetime'] < end)]

# %%
len(df)
# Out:
# 1760

# %%
df.head()
# Out:
#       VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 1251         1  2016-02-01 00:08:23   2016-02-01 00:13:41                  Y
# 2914         2  2016-02-01 03:55:39   2016-02-01 04:15:57                  N
# 3013         2  2016-02-01 03:24:33   2016-02-01 03:38:35                  N
# 3244         2  2016-02-01 04:55:47   2016-02-01 05:12:07                  N
# 3374         2  2016-02-01 04:18:13   2016-02-01 04:30:02                  N
#
#       RateCodeID Pickup_longitude Pickup_latitude Dropoff_longitude  \
# 1251           1   -73.9442138672   40.7464752197    -73.9533233643
# 2914           1   -73.9253463745   40.7616729736    -73.9498596191
# 3013           1   -73.9555206299   40.8043518066    -73.9165725708
# 3244           1   -73.9475021362   40.8012237549    -73.8724136353
# 3374           1   -73.9561691284   40.7463188171    -73.9795150757
#
#      Dropoff_latitude  Passenger_count      ...       Extra  MTA_tax  \
# 1251    40.7282142639                1      ...         0.5      0.5
# 2914    40.8234138489                5      ...         0.5      0.5
# 3013    40.7592697144                1      ...         0.5      0.5
# 3244    40.7743911743                5      ...         0.5      0.5
# 3374    40.7585487366                1      ...         0.5      0.5
#
#       Tip_amount  Tolls_amount  Ehail_fee  improvement_surcharge  \
# 1251        2.65          5.54        NaN                    0.3
# 2914        7.08          5.54        NaN                    0.3
# 3013        1.80          5.54        NaN                    0.3
# 3244        5.67          5.54        NaN                    0.3
# 3374        3.77          5.54        NaN                    0.3
#
#       Total_amount  Payment_type  Trip_type   interval_min
# 1251         15.99             1         1.0      5.300000
# 2914         35.42             1         1.0     20.300000
# 3013         26.14             1         1.0     14.033333
# 3244         34.01             1         1.0     16.333333
# 3374         22.61             1         1.0     11.816667
#
# [5 rows x 22 columns]

# %%
df['interval_min'] = list(map(lambda x:x/60,list(map(lambda x: x.total_seconds(), list(df['Lpep_dropoff_datetime'] - df['lpep_pickup_datetime'])))))
# Out:
# C:\Users\Miya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['weekofday'] = list(map(lambda x: x.weekday(), df['lpep_pickup_datetime']))
# Out:
# C:\Users\Miya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['hour'] = list(map(lambda x: x.hour, df['lpep_pickup_datetime']))
# Out:
# C:\Users\Miya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df['day'] = list(map(lambda x: x.day, df['lpep_pickup_datetime']))
# Out:
# C:\Users\Miya\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime Lpep_dropoff_datetime Store_and_fwd_flag  \
# 0         2  2016-02-01 00:00:01   2016-02-01 00:10:06                  N
# 1         2  2016-02-01 00:01:33   2016-02-01 00:20:13                  N
# 2         2  2016-02-01 00:03:46   2016-02-01 00:21:04                  N
# 3         2  2016-02-01 00:00:05   2016-02-01 00:06:48                  N
# 4         2  2016-02-01 00:06:20   2016-02-01 00:08:47                  N
#
#    RateCodeID  Pickup_longitude  Pickup_latitude  Dropoff_longitude  \
# 0           1        -73.939018        40.805214         -73.972534
# 1           1        -73.891495        40.746651         -73.890877
# 2           1        -73.983780        40.676132         -73.956978
# 3           1        -73.807518        40.700375         -73.831657
# 4           1        -73.903961        40.744934         -73.900009
#
#    Dropoff_latitude  Passenger_count ...   Tolls_amount  Ehail_fee  \
# 0         40.785885                1 ...            0.0        NaN
# 1         40.743896                1 ...            0.0        NaN
# 2         40.718327                1 ...            0.0        NaN
# 3         40.705978                1 ...            0.0        NaN
# 4         40.733601                5 ...            0.0        NaN
#
#    improvement_surcharge  Total_amount  Payment_type  Trip_type   \
# 0                    0.3         11.80             2         1.0
# 1                    0.3         14.30             2         1.0
# 2                    0.3         22.56             1         1.0
# 3                    0.3          9.30             2         1.0
# 4                    0.3          6.30             2         1.0
#
#    interval_min  weekofday  hour  day
# 0     10.083333          0     0    1
# 1     18.666667          0     0    1
# 2     17.300000          0     0    1
# 3      6.716667          0     0    1
# 4      2.450000          0     0    1
#
# [5 rows x 25 columns]

# %%
# %matplotlib inline
plt.hist(df['Tip_amount'].values, range = (0,30),bins = 20)
# Out:
# (array([  4.94041000e+05,   1.37007000e+05,   5.62880000e+04,
#           2.39340000e+04,   1.01750000e+04,   4.34100000e+03,
#           2.76300000e+03,   1.22800000e+03,   7.21000000e+02,
#           3.50000000e+02,   4.73000000e+02,   1.50000000e+02,
#           1.11000000e+02,   2.45000000e+02,   5.80000000e+01,
#           3.20000000e+01,   8.20000000e+01,   3.00000000e+01,
#           1.80000000e+01,   8.10000000e+01]),
#  array([  0. ,   1.5,   3. ,   4.5,   6. ,   7.5,   9. ,  10.5,  12. ,
#          13.5,  15. ,  16.5,  18. ,  19.5,  21. ,  22.5,  24. ,  25.5,
#          27. ,  28.5,  30. ]),
#  <a list of 20 Patch objects>)

# %%
sum(df['Fare_amount']<0)
# Out:
# 1400

# %%
plt.boxplot(df['Fare_amount'].values)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x3c9d149d68>],
#  'caps': [<matplotlib.lines.Line2D at 0x3ca9669828>,
#   <matplotlib.lines.Line2D at 0x3ca9669f60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x3ca966dfd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x3ca966d208>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x3c9d149f28>,
#   <matplotlib.lines.Line2D at 0x3ca9661fd0>]}

# %%
df['Payment_type'].unique()
# Out:
# array([2, 1, 3, 4, 5], dtype=int64)

# %%
plt.boxplot(df['Trip_distance'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x3c9d181d30>],
#  'caps': [<matplotlib.lines.Line2D at 0x3c9d18d780>,
#   <matplotlib.lines.Line2D at 0x3c9d18df98>],
#  'fliers': [<matplotlib.lines.Line2D at 0x3cb2e63ef0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x3cb2e63160>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x3c9d181f60>,
#   <matplotlib.lines.Line2D at 0x3c9d186f28>]}

# %% [markdown]
# # Exploratory Data Analysis

# %%
c.isnull().sum()
# Out:
# VendorID                    0
# lpep_pickup_datetime        0
# Lpep_dropoff_datetime       0
# Store_and_fwd_flag          0
# RateCodeID                  0
# Pickup_longitude            0
# Pickup_latitude             0
# Dropoff_longitude           0
# Dropoff_latitude            0
# Passenger_count             0
# Trip_distance               0
# Fare_amount                 0
# Extra                       0
# MTA_tax                     0
# Tip_amount                  0
# Tolls_amount                0
# Ehail_fee                3705
# improvement_surcharge       0
# Total_amount                0
# Payment_type                0
# Trip_type                   0
# interval_min                0
# dtype: int64

# %%
geolocator = Nominatim()

# %%
geolocator.reverse('40.730610,-73.935242',timeout =10).address.split(',')[-2].strip()
# Out:
# '11101'

# %%
location = geolocator.geocode("Mahattan NYC")

# %%
print((location.latitude, location.longitude))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-8e1d1ec3bd23> in <module>()
# ----> 1 print((location.latitude, location.longitude))
#
# AttributeError: 'NoneType' object has no attribute 'latitude'

# %%
geolocator = Nominatim()
pickup_lat_long = zip(c['Pickup_latitude'],c['Pickup_longitude'])
dropoff_lat_long = zip(c['Dropoff_latitude'],c['Dropoff_longitude'])
pickup_zipcode = []
dropoff_zipcode = []

for i,j in pickup_lat_long:
    try:
        zipcode = geolocator.reverse(','.join([i,j]),timeout=10).address.split(',')[-2].strip()
        pickup_zipcode.append(zipcode)
    except AttributeError:
        pickup_zipcode.append(' ')
        
for i,j in dropoff_lat_long:
    try:
        zipcode = geolocator.reverse(','.join([i,j]),timeout=10).address.split(',')[-2].strip()
        dropoff_zipcode.append(zipcode)
    except AttributeError:
        dropoff_zipcode.append(' ')
    
c['pickup_zipcode'] = pickup_zipcode
c['dropoff_zipcode'] = dropoff_zipcode
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# C:\Users\Miya\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     142         try:
# --> 143             page = requester(req, timeout=(timeout or self.timeout), **kwargs)
#     144         except Exception as error: # pylint: disable=W0703
#
# C:\Users\Miya\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#
# C:\Users\Miya\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     471             meth = getattr(processor, meth_name)
# --> 472             response = meth(req, response)
#     473
#
# C:\Users\Miya\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     581             response = self.parent.error(
# --> 582                 'http', request, response, code, msg, hdrs)
#     583
#
# C:\Users\Miya\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     509             args = (dict, 'default', 'http_error_default') + orig_args
# --> 510             return self._call_chain(*args)
#     511
#
# C:\Users\Miya\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     443             func = getattr(handler, meth_name)
# --> 444             result = func(*args)
#     445             if result is not None:
#
# C:\Users\Miya\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     589     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 590         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     591
#
# HTTPError: HTTP Error 429: Too Many Requests
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\Miya\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     157                 try:
# --> 158                     raise ERROR_CODE_MAP[code](message)
#     159                 except KeyError:
#
# KeyError: 429
#
# During handling of the above exception, another exception occurred:
#
# GeocoderServiceError                      Traceback (most recent call last)
# <ipython-input-56-a4313ae41f5a> in <module>()
#       7 for i,j in pickup_lat_long:
#       8     try:
# ----> 9         zipcode = geolocator.reverse(','.join([i,j]),timeout=10).address.split(',')[-2].strip()
#      10         pickup_zipcode.append(zipcode)
#      11     except AttributeError:
#
# C:\Users\Miya\Anaconda3\lib\site-packages\geopy\geocoders\osm.py in reverse(self, query, exactly_one, timeout, language)
#     246         logger.debug("%s.reverse: %s", self.__class__.__name__, url)
#     247         return self._parse_json(
# --> 248             self._call_geocoder(url, timeout=timeout), exactly_one
#     249         )
#     250
#
# C:\Users\Miya\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     158                     raise ERROR_CODE_MAP[code](message)
#     159                 except KeyError:
# --> 160                     raise GeocoderServiceError(message)
#     161             elif isinstance(error, URLError):
#     162                 if "timed out" in message:
#
# GeocoderServiceError: HTTP Error 429: Too Many Requests

# %%
len(pickup_zipcode)
# Out:
# 1582

# %%
len(c)
# Out:
# 3705

# %%
lat = df['Dropoff_latitude'][3]
long = df['Dropoff_longitude'][3]
county = geolocator.reverse(','.join([lat,long])).address.split(',')[-5].strip()
city = geolocator.reverse(','.join([lat,long])).address.split(',')[-4].strip()
state = geolocator.reverse(','.join([lat,long])).address.split(',')[-3].strip()
zipcode = geolocator.reverse(','.join([lat,long])).address.split(',')[-2].strip()
street = geolocator.reverse(','.join([lat,long])).address.split(',')[-6].strip()
